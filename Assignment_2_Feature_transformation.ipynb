# %% [markdown]
# # ***To Do :***
# 1. Normalization
# 2. Standardization
# 3. Robust Scaler
# 4. Max Absolute Scaler

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv('/content/supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1= df.copy()
df2= df.copy()
df3 = df.copy()
df4 = df.copy()

# %% [markdown]
# # ***Normalization***

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler(feature_range=(5,10))

# %%
#Marketing Spend
Marketing_nor = scaler.fit(df1[['Marketing Spend']])

# %%
df1['Marketing Spend'] = scaler.transform(df1[['Marketing Spend']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         8.463083       136897.80  471784.10    Dhaka  192261.83
# 1         9.916797       151377.59  443898.53      Ctg  191792.06
# 2         9.639923       101145.55  407934.54  Rangpur  191050.39
# 3         9.365682       118671.85  383199.62    Dhaka  182901.99
# 4         9.297189        91391.77  366168.42  Rangpur  166187.94

# %%
#Administration
Admin_nor = scaler.fit(df1[['Administration']])

# %%
df1['Administration']=scaler.transform(df1[['Administration']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         8.463083        8.258720  471784.10    Dhaka  192261.83
# 1         9.916797        8.809859  443898.53      Ctg  191792.06
# 2         9.639923        6.897895  407934.54  Rangpur  191050.39
# 3         9.365682        7.564992  383199.62    Dhaka  182901.99
# 4         9.297189        6.526640  366168.42  Rangpur  166187.94

# %%
#Transport
Trans_nor = scaler.fit(df1[['Transport']])

# %%
df1['Transport']=scaler.transform(df1[['Transport']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         8.463083        8.258720  10.000000    Dhaka  192261.83
# 1         9.916797        8.809859   9.704467      Ctg  191792.06
# 2         9.639923        6.897895   9.323318  Rangpur  191050.39
# 3         9.365682        7.564992   9.061176    Dhaka  182901.99
# 4         9.297189        6.526640   8.880678  Rangpur  166187.94

# %%
#Profit
Profit_nor = scaler.fit(df1[['Profit']])

# %%
df1['Profit']=scaler.transform(df1[['Profit']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         8.463083        8.258720  10.000000    Dhaka  10.000000
# 1         9.916797        8.809859   9.704467      Ctg   9.986773
# 2         9.639923        6.897895   9.323318  Rangpur   9.965890
# 3         9.365682        7.564992   9.061176    Dhaka   9.736462
# 4         9.297189        6.526640   8.880678  Rangpur   9.265857

# %% [markdown]
# # **Standardization**

# %%
df2.head(4)
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
Marketing_std= scaler.fit(df2[['Marketing Spend']])

# %%
df2['Marketing Spend']=scaler.transform(df2[['Marketing Spend']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %%
Admin_std = scaler.fit(df2[['Administration']])

# %%
df2['Administration'] = scaler.transform(df2[['Administration']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753  471784.10    Dhaka  192261.83
# 1         1.955860        1.082807  443898.53      Ctg  191792.06
# 2         1.754364       -0.728257  407934.54  Rangpur  191050.39
# 3         1.554784       -0.096365  383199.62    Dhaka  182901.99
# 4         1.504937       -1.079919  366168.42  Rangpur  166187.94

# %%
Trans_std = scaler.fit(df2[['Transport']])

# %%
df2['Transport']= scaler.transform(df2[['Transport']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        0.560753   2.165287    Dhaka  192261.83
# 1         1.955860        1.082807   1.929843      Ctg  191792.06
# 2         1.754364       -0.728257   1.626191  Rangpur  191050.39
# 3         1.554784       -0.096365   1.417348    Dhaka  182901.99
# 4         1.504937       -1.079919   1.273550  Rangpur  166187.94

# %%
Profit_std = scaler.fit(df2[['Profit']])

# %%
df2['Profit']=scaler.transform(df2[['Profit']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.560753   2.165287    Dhaka  2.011203
# 1         1.955860        1.082807   1.929843      Ctg  1.999430
# 2         1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3         1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4         1.504937       -1.079919   1.273550  Rangpur  1.357740

# %% [markdown]
# # ***Robust Scaler***

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()

# %%
df3['Marketing Spend'] =rs.fit_transform(df3[['Marketing Spend']])
df3['Administration'] =rs.fit_transform(df3[['Administration']])
df3['Transport'] =rs.fit_transform(df3[['Transport']])
df3['Profit'] =rs.fit_transform(df3[['Profit']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.345355   1.552016    Dhaka  1.698340
# 1         1.452113        0.697565   1.383714      Ctg  1.688874
# 2         1.303634       -0.524290   1.166654  Rangpur  1.673929
# 3         1.156567       -0.097977   1.017368    Dhaka  1.509736
# 4         1.119836       -0.761543   0.914576  Rangpur  1.172943

# %% [markdown]
# # ***Max Absolute Scaler***

# %%
df4.Transport = df4.Transport/ df4.Transport.max()
df4.Administration = df4.Administration/ df4.Administration.max()
df4.Transport = df4.Transport/ df4.Transport.max()
df4.Profit = df4.Profit/ df4.Profit.max()
df4['Marketing Spend'] = df4['Marketing Spend']/ df4['Marketing Spend'].max()

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.749527   1.000000    Dhaka  1.000000
# 1         0.983359        0.828805   0.891559      Ctg  0.997557
# 2         0.927985        0.553781   0.751702  Rangpur  0.993699
# 3         0.873136        0.649738   0.655513    Dhaka  0.951317
# 4         0.859438        0.500378   0.589283  Rangpur  0.864383

# %% [markdown]
# ## Summarize

# %%
df1.head() #Normalize
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         8.463083        8.258720  10.000000    Dhaka  10.000000
# 1         9.916797        8.809859   9.704467      Ctg   9.986773
# 2         9.639923        6.897895   9.323318  Rangpur   9.965890
# 3         9.365682        7.564992   9.061176    Dhaka   9.736462
# 4         9.297189        6.526640   8.880678  Rangpur   9.265857

# %%
df2.head() # Standardize
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.560753   2.165287    Dhaka  2.011203
# 1         1.955860        1.082807   1.929843      Ctg  1.999430
# 2         1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3         1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4         1.504937       -1.079919   1.273550  Rangpur  1.357740

# %%
df3.head() # Robust Scaler
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.345355   1.000000    Dhaka  1.698340
# 1         1.452113        0.697565   0.891559      Ctg  1.688874
# 2         1.303634       -0.524290   0.751702  Rangpur  1.673929
# 3         1.156567       -0.097977   0.655513    Dhaka  1.509736
# 4         1.119836       -0.761543   0.589283  Rangpur  1.172943

# %%
df4.head() # MAS
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.749527   1.000000    Dhaka  1.000000
# 1         0.983359        0.828805   0.891559      Ctg  0.997557
# 2         0.927985        0.553781   0.751702  Rangpur  0.993699
# 3         0.873136        0.649738   0.655513    Dhaka  0.951317
# 4         0.859438        0.500378   0.589283  Rangpur  0.864383

# %% [markdown]
# # ***The End***
# Boss I think I am done
